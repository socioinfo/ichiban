# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !unzip ./ichiban-main.zip
# Out:
# Archive:  ./ichiban-main.zip
# 769861a8adc68182565cac7bfacf248024150370
#    creating: ichiban-main/
#   inflating: ichiban-main/.gitignore
#  extracting: ichiban-main/README.md
#    creating: ichiban-main/chapter4flask/
#   inflating: ichiban-main/chapter4flask/README.md
#   inflating: ichiban-main/chapter4flask/book_data.tsv
#   inflating: ichiban-main/chapter4flask/make_markov-dict.py
#   inflating: ichiban-main/chapter4flask/markov-dict.pickle
#   inflating: ichiban-main/chapter4flask/pybot.py
#   inflating: ichiban-main/chapter4flask/pybot.txt
#   inflating: ichiban-main/chapter4flask/pybot_book.py
#   inflating: ichiban-main/chapter4flask/pybot_datetime.py
#   inflating: ichiban-main/chapter4flask/pybot_eto.py
#   inflating: ichiban-main/chapter4flask/pybot_markov.py
#   inflating: ichiban-main/chapter4flask/pybot_random.py
#   inflating: ichiban-main/chapter4flask/pybot_sum.py
#   inflating: ichiban-main/chapter4flask/pybotweb.py
# ...

# %%
# %cd ichiban-main
# Out:
# /content/drive/MyDrive/ichiban-main

# %%
# %cd chapter4flask
# Out:
# /content/drive/MyDrive/ichiban-main/chapter4flask

# %%
# !pip install flask-ngrok
# !pip install flask==0.12.2
# Out:
# ...
#      |████████████████████████████████| 83 kB 1.0 MB/s
# ...
#   Attempting uninstall: flask
#     Found existing installation: Flask 1.1.4
#     Uninstalling Flask-1.1.4:
#       Successfully uninstalled Flask-1.1.4
# ...

# %%
# !python ./pybotweb.py
# Out:
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://0472-35-201-142-5.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [03/Nov/2021 14:40:39] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [03/Nov/2021 14:40:40] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [03/Nov/2021 14:40:44] "GET /hello HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Nov/2021 14:40:49] "POST /hello HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Nov/2021 14:41:12] "POST /hello HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Nov/2021 14:41:18] "POST /hello HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Nov/2021 14:41:23] "POST /hello HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Nov/2021 14:41:30] "POST /hello HTTP/1.1" 200 -
# ^C
